# %%
import random             #importing the libraries needed
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt 
from sklearn.cluster import KMeans 
from sklearn.datasets.samples_generator import make_blobs 
# %matplotlib inline
# Out:
# /home/aisha/anaconda3/lib/python3.8/site-packages/sklearn/utils/deprecation.py:143: FutureWarning: The sklearn.datasets.samples_generator module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.datasets. Anything that cannot be imported from sklearn.datasets is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
df = pd.read_csv("ONLY_WICKET_KEEPER_AVG_POINTS.csv")   #reading the dataset
y=list(df['Stumping'])                                  #creating the list of values in Stumping colmn
df=df[['Stumping','strike_rate','catch']]               #viewing selected columns
# y=list(df['fp_points'])
# # df = df[['batsman_runs','strike_rate','economy','wickets']]
# # df.tail(20)
# print(y.count(0))
# print(len(y))
df
# Out:
#       Stumping  strike_rate  catch
# 0            0   158.823529      0
# 1            0   141.176471      0
# 2            0    66.666667      0
# 3            0    66.666667      0
# 4            0   131.578947      0
# ...        ...          ...    ...
# 1662         0     0.000000      0
# 1663         0   166.666667      1
# 1664         0   170.175439      1
# 1665         0    84.210526      2
# 1666         0    88.461538      1
#
# [1667 rows x 3 columns]

# %%
from sklearn.preprocessing import StandardScaler    #importing StandarScaler
X = df.values[:,0:]                                 #taking all the values from the column
X = np.nan_to_num(X)                                #substitutes any NaN values with numerical values
Clus_dataSet = StandardScaler().fit_transform(X)    #normalizes the data
Clus_dataSet                                        #display the array
# Out:
# array([[-0.15490347,  0.7442659 , -0.49480326],
#        [-0.15490347,  0.45820473, -0.49480326],
#        [-0.15490347, -0.74960909, -0.49480326],
#        ...,
#        [-0.15490347,  0.92828185,  1.02703628],
#        [-0.15490347, -0.4652208 ,  2.54887583],
#        [-0.15490347, -0.39631132,  1.02703628]])

# %%
clusterNum = 5                                                              #cluster number = 5
k_means = KMeans(init = "k-means++", n_clusters = clusterNum, n_init = 15)  #k means clustering for cluster num = 5
k_means.fit(X)                                                              #fitting the clusters
labels = k_means.labels_                                                    #labels for each point in the model
print(labels)                                                               #print the labels
# Out:
# [0 0 3 ... 4 3 3]

# %%
points=[]                     #condition for 5 classes
for i in labels:              #for loop for the labels for each point obtained above
    if(i==0):                 #if i=0, then it falls in class 9
        points.append(9)
#   elif(i==9):
#     points.append(8)
    elif(i==1):
        points.append(8)      #if i=1, then it falls in class 8
#   elif(i==8):
#     points.append(10)
#   elif(i==7):
#     points.append(8.5)
    elif(i==2):
        points.append(10)     #if i=2, then it falls in class 10
    elif(i==3):
        points.append(8.5)    #if i=3, then it falls in class 8.5
    elif(i==4):
        points.append(9.5)    #if i=4, then it falls in class 9.5
#   elif(i==4):
#     points.append(9.5)
#   elif(i==6):
#     points.append(9.5)
 
print(points)                 #printing the points
# Out:
# [9, 9, 8.5, 8.5, 9, 9, 9, 9, 9, 8, 8, 9.5, 9, 8, 9, 8.5, 9, 8, 8, 8.5, 9.5, 9, 9.5, 9, 8, 8.5, 8.5, 9, 9, 8, 9, 9, 9.5, 9, 8.5, 8.5, 8.5, 9, 8.5, 9, 9.5, 8.5, 8.5, 9, 8.5, 8.5, 9, 9.5, 8.5, 8.5, 8, 9.5, 8, 8, 9.5, 8.5, 9, 9, 9.5, 9, 8.5, 8, 9, 8.5, 9.5, 9.5, 9, 9.5, 9, 9.5, 8.5, 8.5, 8.5, 9, 8.5, 9.5, 9, 8, 9, 9, 9.5, 8.5, 9, 8, 9.5, 9.5, 9, 9.5, 9, 8.5, 9.5, 9, 9, 9.5, 9, 10, 8.5, 8.5, 9, 8.5, 9.5, 9.5, 9, 9.5, 9.5, 8.5, 9, 8.5, 9, 9.5, 9, 9, 9, 9, 9, 9, 9.5, 9, 8.5, 8.5, 8.5, 9.5, 8, 9, 8, 8, 9, 9, 9, 9.5, 9, 9, 8, 8.5, 9, 9.5, 8, 8.5, 9.5, 9, 9, 8.5, 9, 8.5, 9, 8, 9.5, 8.5, 8, 8.5, 8.5, 8.5, 9.5, 8.5, 9.5, 9, 8.5, 8, 9, 8.5, 9, 8.5, 8.5, 9, 8, 9, 9, 9, 8.5, 8.5, 9.5, 9.5, 9.5, 9.5, 9, 9.5, 9.5, 9, 9, 9, 8.5, 9.5, 8, 9.5, 9.5, 8.5, 9, 8.5, 8, 8, 9.5, 9, 9, 8.5, 9.5, 9, 9.5, 8.5, 9.5, 8, 8, 9, 8, 8, 8, 8.5, 8.5, 8.5, 9, 9, 8.5, 9.5, 9.5, 8.5, 9, 8, 8.5, 8.5, 9, 8, 9, 9, 9, 8, 8.5, 9.5, 8, 9, 8.5, 9.5, 8.5, 9, 8, 8.5, 8.5, 9, 8, 8.5, 9, 9, 8, 8.5, 8.5, 8.5, 9, 8.5, 8, 9, 9, 9, 8.5, 8
# ...

# %%
df_new = df                 #creating new dataset and storing the points
df_new["Points"] = points
# df_new.to_csv("all_rnd_points.csv")

# %%
df_new.groupby(points).mean()   #viewing the dataset where it is grouped by points and mean is taken
# Out:
#       Stumping  strike_rate     catch  Points
# 8.0   0.023256    24.079740  0.292359     8.0
# 8.5   0.023857    87.638253  0.286282     8.5
# 9.0   0.032028   135.253993  0.316726     9.0
# 9.5   0.042553   193.716225  0.432624     9.5
# 10.0  0.052632   328.950244  0.526316    10.0

# %%
from mpl_toolkits.mplot3d import Axes3D                   #plotting the clusters obtained
fig = plt.figure(1, figsize=(8, 6))
plt.clf()
ax = Axes3D(fig, rect=[0, 0, .95, 1], elev=48, azim=134)  

plt.cla()
ax.set_xlabel('strike_rate')
ax.set_zlabel('catch')
ax.set_ylabel('Stumping')


y=ax.scatter(X[:,1] ,X[:,0],X[:,2],c= points)             
cbar=plt.colorbar(y,pad=0.10,fraction=0.02,shrink=50.0)

# %%
df = pd.read_csv("ONLY_WICKET_KEEPER_AVG_POINTS.csv")

df['rating']=df_new['Points']

# %%
df.to_csv("only_wk_avg_points.csv")
